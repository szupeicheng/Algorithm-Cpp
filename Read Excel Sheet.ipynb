# %%
import pandas as pd
xlsx = pd.ExcelFile("16_sa05_cy_B0110O14_315a_01181115.xls")
df = pd.read_excel(xlsx, "Statistics_1-016", index_col=1)

# %%
df
# Out:
#                Cycle_Index  Test_Time(m)           Date_Time  Current(A)  \
# Test_Time(s)
# 5495.572711              1     91.592879 2008-01-18 12:46:56   -0.000500
# 14487.097128             2    241.451619 2008-01-18 15:16:49   -0.000501
# 23478.524922             3    391.308749 2008-01-18 17:46:41   -0.000501
# 32470.505979             4    541.175100 2008-01-18 20:16:35   -0.000500
# 41456.885043             5    690.948084 2008-01-18 22:46:22   -0.000501
# 50430.657219             6    840.510954 2008-01-19 01:15:58   -0.000500
# 59398.548873             7    989.975815 2008-01-19 03:45:27   -0.000501
# 68338.549668             8   1138.975828 2008-01-19 06:14:28   -0.000501
# 77287.678893             9   1288.127982 2008-01-19 08:43:39   -0.000501
# 86248.725911            10   1437.478765 2008-01-19 11:13:02   -0.000501
# 95220.662546            11   1587.011042 2008-01-19 13:42:35   -0.000500
# 104197.862976           12   1736.631050 2008-01-19 16:12:14   -0.000501
# ...
